# %% [markdown]
# ### Exercise 1 - Turn the shopping cart program from yesterday into an object-oriented program

# %%
class Cart():

    def __init__ (self, cart = {}):
        self.cart = cart
        #self.total = 0

    def shop(self):
        item = input("What would you like to get? ").title()
        quantity = int(input(f'How many {item} would you like to get? '))
        price = float(input(f"Price of the {item} is $"))
        self.cart[item] = [quantity, price]
        #self.total += price*quantity
        #self.cart.update({item:quantity}) # yeni bir dict degil de eski dicte eklenen yenisiyle update ediyor, biraz set bitlestirme gibi
                
    def view(self):
        for item in self.cart:
            print(f'{item.title()}: {self.cart[item][0]} * ${self.cart[item][1]}')

    def remove(self):
        while True:
            response = input('\nWhich item would you like to remove? ').title()
            if not response in self.cart:
                print(f'{response} is not in the cart.')
            else:
                del self.cart[response]
                print(f'{response} has been removed from the cart.')
            
            second_response = input("\nWould you like to delete another item? \n'Yes' or 'No'\n").title()
            if second_response == 'No':
                break
              
    def clear(self):
        self.cart.clear()
        
    def check_out(self):
        item_total = []
        for key in self.cart:
            total = self.cart[key][0] * self.cart[key][1] 
            item_total.append(total)
            print(f'{key.title()}: {self.cart[key][0]} * ${self.cart[key][1]} = ${total}')
            total_cost = sum(item_total)
            print('-'*10)
            print('Total: $' + str(total_cost))

# %%
my_cart = Cart({})
while True:
    #try:
    ask = input("What would you like to do? \n'Shop' 'View Cart' 'Remove Item' 'Clean Cart' 'Check Out' 'Quit'\n").title()
    if ask == 'Quit':
        my_cart.check_out()
        print('Thank you for visiting us!')
        break
    elif ask == 'Shop':
        my_cart.shop()
    elif ask == 'View Cart':
        print(f'\nYour current cart: ')
        my_cart.view()       
    elif ask == 'Remove Item':
        my_cart.remove()
    elif ask == 'Clean Cart':
        my_cart.clear()
        print('YOUR CART IS EMPTY NOW!')
    elif ask == 'Check Out':
        print('Ready to check out?')
        print("="*15)
        my_cart.check_out()
    else:
        print('PLEASE CHOOSE A VALID ANSWER!')
#     except: 
#         print('Please enter correct data type.')
# Out:
# What would you like to do?
# 'Shop' 'View Cart' 'Remove Item' 'Clean Cart' 'Check Out' 'Quit'
# shop
# What would you like to get? aplle
# How many Aplle would you like to get? 3
# Price of the Aplle is $3
# What would you like to do?
# 'Shop' 'View Cart' 'Remove Item' 'Clean Cart' 'Check Out' 'Quit'
# shop
# What would you like to get? orange
# How many Orange would you like to get? 3
# Price of the Orange is $3
# What would you like to do?
# 'Shop' 'View Cart' 'Remove Item' 'Clean Cart' 'Check Out' 'Quit'
# view cart
#
# Your current cart:
# Aplle: 3 * $3.0
# Orange: 3 * $3.0
# What would you like to do?
# 'Shop' 'View Cart' 'Remove Item' 'Clean Cart' 'Check Out' 'Quit'
# remove item
#
# Which item would you like to remove? orange
# Orange has been removed from the cart.
#
# Would you like to delete another item?
# 'Yes' or 'No'
# no
# What would you like to do?
# 'Shop' 'View Cart' 'Remove Item' 'Clean Cart' 'Check Out' 'Quit'
# check out
# Ready to check out?
# ===============
# Aplle: 3 * $3.0 = $9.0
# ----------
# Total: $9.0
# What would you like to do?
# 'Shop' 'View Cart' 'Remove Item' 'Clean Cart' 'Check Out' 'Quit'
# clean cart
# YOUR CART IS EMPTY NOW!
# What would you like to do?
# 'Shop' 'View Cart' 'Remove Item' 'Clean Cart' 'Check Out' 'Quit'
# quit
# Thank you for visiting us!

# %% [markdown]
# ### Exercise 2 - Write a Python class which has two methods get_String and print_String. get_String accept a string from the user and print_String print the string in upper case

# %%
class Uppercase:
    def __init__(self):
        self.string = ""
    def getString(self):
        self.string = input('Type anything here: ')
    def upper(self):
        return self.string.upper()
        
case = Uppercase()
case.getString()
case.upper()
# Out:
# Type anything here: elif
# 'ELIF'
